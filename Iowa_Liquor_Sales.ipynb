# %% [markdown]
# <a href="https://colab.research.google.com/github/sennylim/SQL-Iowa/blob/main/Iowa_Liquor_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Total sales by year

# %%
df = pd.read_csv(r"/content/0.csv")
df.total_sales = round(df.total_sales/1000000,2)

##
fig = px.line(df, x="years", y="total_sales",
              text="total_sales",
              line_shape='spline')

fig.update_traces(textposition="bottom right")

fig.update_layout(
    title={
        "text": f"Total Sales '12 - '23",
        "y": 0.95,
        "x": 0.5,
        "xanchor": "center",
        "yanchor": "top",
    },
    yaxis_title="Total Sales ($M)")


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b0090e3c-928e-44c6-a34f-a2c39795d3e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0090e3c-928e-44c6-a34f-a2c39795d3e5")) {                    Plotly.newPlot(                        "b0090e3c-928e-44c6-a34f-a2c39795d3e5",                        [{"hovertemplate":"years=%{x}\u003cbr\u003etotal_sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid","shape":"spline"},"marker":{"symbol":"circle"},"mode":"markers+text+lines","name":"","orientation":"v","showlegend":false,"text":[290.46,428.78,428.12,396.66,349.22,334.22,314.53,299.45,284.33,270.59,258.1,255.2],"x":[2023,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012],"xaxis":"x","y":[290.46,428.78,428.12,396.66,349.22,334.22,314.53,299.45,284.33,270.59,258.1,255.2],"yaxis":"y","type":"scatter","textposition":"bottom right"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y" ...

# %% [markdown]
# # Sales Trend '18 - '23

# %%
df1_1 = pd.read_csv(r"/content/13.csv")
df1_1.columns = ['Years', 'Total Sales', 'YoY Change(%)']
df1_1
# Out:
#    Years  Total Sales  YoY Change(%)
# 0   2022    428780003            0.2
# 1   2021    428123535            7.9
# 2   2020    396663132           13.6
# 3   2019    349220342            4.5
# 4   2018    334216843            6.3
# 5   2017    314530045            NaN

# %% [markdown]
# # Consumption Trend

# %%
df1_2 = pd.read_csv(r"/content/consumption.csv")
df1_2.columns = ['Years', 'Total Liters', 'YoY Change(%)']
df1_2
# Out:
#    Years  Total Liters  YoY Change(%)
# 0   2022    23566096.0           -4.8
# 1   2021    24755365.0            2.2
# 2   2020    24211661.0            8.6
# 3   2019    22301422.0            1.9
# 4   2018    21895982.0            3.8
# 5   2017    21096850.0            NaN

# %% [markdown]
# # Which days have the highest sales?

# %%
df1_3 = pd.read_csv(r"/content/1.csv")
df1_3.total_sales = round(df1_3.total_sales/1000000,2)

##
fig = px.bar(df1_3, y='total_sales', x='days', text='total_sales')

fig.update_traces(textposition='outside', marker_color = 'rgb(44, 73, 172, 50)')

fig.update_layout(
    {'plot_bgcolor': 'rgba(255,255,255, 0.9)'},
    title = {
        "text": f"Total Liquor Sales by Weekday ('12 - '23)",
        "y": .98,
        "x": .5,
        "xanchor": "center",
        "yanchor": "top",
    },
    yaxis_title="Total Sales ($M)",
    xaxis={
        "categoryarray": [
            "Monday",
            "Tuesday",
            "Wednesday",
            "Thursday",
            "Friday",
            "Saturday",
            "Sunday",
        ]
    },
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="149c85a3-f4c1-4184-ade8-e86e91d42165" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("149c85a3-f4c1-4184-ade8-e86e91d42165")) {                    Plotly.newPlot(                        "149c85a3-f4c1-4184-ade8-e86e91d42165",                        [{"alignmentgroup":"True","hovertemplate":"days=%{x}\u003cbr\u003etotal_sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(44, 73, 172, 50)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[884.5,864.41,838.24,806.68,484.83,28.69,2.32],"textposition":"outside","x":["Wednesday","Monday","Tuesday","Thursday","Friday","Saturday","Sunday"],"xaxis":"x","y":[884.5,864.41,838.24,806.68,484.83,28.69,2.32],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"f ...

# %% [markdown]
# # Which months have the highest sales?

# %%
df2 = pd.read_csv(r"/content/2.csv")
df2.total_sales = round(df2.total_sales/1000000,2)

##
fig = px.bar(df2, x='total_sales', y = 'months', text = 'total_sales')

month = [
    'December',
    'November',
    'October',
    'September',
    'August',
    'July',
    'June',
    'May',
    'April',
    'March',
    'February',
    'January',
]

fig.update_traces(textposition='inside', marker_color='rgb(44, 73, 172, 50)')

fig.update_layout(
    {'plot_bgcolor': 'rgba(255,255,255, 0.9)'},
    title = {
        "text": f"Total Liquor Sales by Month ('12 - '23)",
        "y": .98,
        "x": .5,
        "xanchor": "center",
        "yanchor": "top",
    },
    yaxis_title = 'Months',
    yaxis = {'categoryarray': month},
    xaxis_title = 'Total Sales ($M)',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ad5d7e50-9bd7-45ad-9927-907e2d656b7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad5d7e50-9bd7-45ad-9927-907e2d656b7d")) {                    Plotly.newPlot(                        "ad5d7e50-9bd7-45ad-9927-907e2d656b7d",                        [{"alignmentgroup":"True","hovertemplate":"total_sales=%{text}\u003cbr\u003emonths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(44, 73, 172, 50)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[373.33,361.24,359.7,348.81,346.36,331.13,321.9,312.03,301.23,295.77,287.1,271.07],"textposition":"inside","x":[373.33,361.24,359.7,348.81,346.36,331.13,321.9,312.03,301.23,295.77,287.1,271.07],"xaxis":"x","y":["December","June","October","August","May","July","April","March","November","September","February","January"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x": ...

# %% [markdown]
# # Sales by Month '21 to '22

# %%
df4_1 = pd.read_csv(r"/content/4_1.csv")
df4_1.total_sales = round(df4_1.total_sales/1000000,2)

df4_1[['month', 'year']] = df4_1.month_year.str.split(" ", expand = True)

##
color21=['rgb(90,140,219,86)']
color22=['rgb(44, 73, 172, 50)']

fig= px.bar(df4_1, x='month', y='total_sales',
color='year', barmode='group',color_discrete_sequence=color21+color22)

fig.update_layout(
    title = {
        "text": f"Total Liquor Sales by month ('21 - '22)",
        "y": .98,
        "x": .5,
        "xanchor": "center",
        "yanchor": "top",
    },
    yaxis_title="Total Sales ($M)",
    xaxis_title="Months",
    xaxis={
        "categoryarray": [
            "Jan",
            'Feb',
            'Mar',
            'Apr',
            'May',
            'Jun',
            'Jul',
            'Aug',
            'Sep',
            'Oct',
            'Nov',
            'Dec',
        ]
    },)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ff56f52c-d1d0-46b6-a853-da8f7651cc0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff56f52c-d1d0-46b6-a853-da8f7651cc0c")) {                    Plotly.newPlot(                        "ff56f52c-d1d0-46b6-a853-da8f7651cc0c",                        [{"alignmentgroup":"True","hovertemplate":"year=2021\u003cbr\u003emonth=%{x}\u003cbr\u003etotal_sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2021","marker":{"color":"rgb(90,140,219,86)","pattern":{"shape":""}},"name":"2021","offsetgroup":"2021","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"xaxis":"x","y":[34.73,36.5,42.29,29.62,28.67,35.18,38.89,36.65,33.66,38.01,38.09,35.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2022\u003cbr\u003emonth=%{x}\u003cbr\u003etotal_sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2022","marker":{"color":"rgb(44, 73, 172, 50)","pattern":{"shape":""}},"name":"2022","offsetgroup":"2022","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr","Aug","Dec","Feb","Jan","Jul","Jun","Mar","May","Nov","Oct","Sep"],"xaxis":"x","y":[34.78,41.37,43.15,29.47,27.6,33.79,38.61,30.23,35.95,37.51,39.69,36.62],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888 ...

# %% [markdown]
# # Item & Category Revenue (2022)

# %% [markdown]
# * **By Bottle**

# %%
df5 = pd.read_csv(r"/content/5.csv")

df5.total_sales = round(df5.total_sales/1000000,2)
df5.bottle_sales = round(df5.bottle_sales/100000,2)

df5.category = df5.category.str.title()
df5.item = df5.item.str.title()
df5.total_sales = df5.total_sales.astype('float')
df5.bottle_sales = df5.bottle_sales.astype('float')

cat2022 = (
    df5.sort_values(by="bottle_sales", ascending=False)
    .head(10)
    .copy())

cat2022 = cat2022.sort_values(by="bottle_sales", ascending = True)

fig = px.bar(
    cat2022,
x = "bottle_sales",
y = 'item',
orientation = 'h',
text = 'bottle_sales',
color = 'category',
)

fig.update_traces(textposition = 'inside')

fig.update_layout(
    {'plot_bgcolor': 'rgba(255,255,255, 0.9)'},
    title = {
        'text':f'Item & Category - By Bottle (2022)',
        'y': .98,
        'x':.5,
        'xanchor': 'center',
        'yanchor': 'top',
    },
    yaxis_title = "Item Name",
    xaxis_title = 'Bottle Sales (by Million)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e23b95cd-b8d9-4cd1-8bf5-2b0672c5a6fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e23b95cd-b8d9-4cd1-8bf5-2b0672c5a6fd")) {                    Plotly.newPlot(                        "e23b95cd-b8d9-4cd1-8bf5-2b0672c5a6fd",                        [{"alignmentgroup":"True","hovertemplate":"category=Tennessee Whiskies\u003cbr\u003ebottle_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tennessee Whiskies","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Tennessee Whiskies","offsetgroup":"Tennessee Whiskies","orientation":"h","showlegend":true,"text":[3.51],"textposition":"inside","x":[3.51],"xaxis":"x","y":["Jack Daniels Old #7 Black Label"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Canadian Whiskies\u003cbr\u003ebottle_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canadian Whiskies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Canadian Whiskies","offsetgroup":"Canadian Whiskies","orientation":"h","showlegend":true,"text":[4.34,4.47,11.21],"textposition":"inside","x":[4.34,4.47,11.21],"xaxis":"x","y":["Crown Royal","Crown Royal Regal Apple","Black Velvet"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=American Vodkas\u003cbr\u003ebottle_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Vodkas","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"American Vodkas","offsetgroup":"American Vodkas","orientation":"h","showlegend":true,"text":[5.47,6.92,14.59],"textposition":"inside","x":[5.47,6.92,14.59],"xaxis":"x","y":["Mccormick 80Prf Vodka Pet","Hawkeye Vodka","Titos Handmade Vodka"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Whiskey Liqueur\u003cbr\u003ebottle_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Whiskey Liqueur","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Whiskey Liqueur","offsetgroup":"Whiskey Liqueur","orientation":"h","showlegend":true,"text":[5.57,30.25],"textposition":"inside","x":[5.57,30.25],"xaxis":"x","y":["Fireball Cinnamon Whiskey Mini Sleeve","Fireball Cinnamon Whiskey"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Spiced Rum\u003cbr\u003ebottle_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spiced Rum","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Spiced Rum","offsetgroup":"Spiced Rum","orientation":"h","showlegend":true,"text":[6.4],"textposition":"inside","x":[6.4],"xaxis":"x","y":["Captain Morgan Original Spiced"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# * **By Sales**

# %%
item2022 = (
    df5.sort_values(by="total_sales", ascending=False)
    .head(10)
    .copy())

item2022 = item2022.sort_values(by="total_sales", ascending = True)

fig = px.bar(
    item2022,
x = "total_sales",
y = 'item',
orientation = 'h',
text = 'total_sales',
color = 'category',
)

fig.update_traces(textposition = 'inside')

fig.update_layout(
    {'plot_bgcolor': 'rgba(255,255,255, 0.9)'},
    title = {
        'text':f'Item & Category - By Sales (2022)',
        'y': .98,
        'x':.5,
        'xanchor': 'center',
        'yanchor': 'top',
    },
    yaxis_title = "Item Name",
    xaxis_title = 'Total Sales',)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45170c4b-3eda-47e6-a752-229d2d55e37d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45170c4b-3eda-47e6-a752-229d2d55e37d")) {                    Plotly.newPlot(                        "45170c4b-3eda-47e6-a752-229d2d55e37d",                        [{"alignmentgroup":"True","hovertemplate":"category=100% Agave Tequila\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"100% Agave Tequila","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"100% Agave Tequila","offsetgroup":"100% Agave Tequila","orientation":"h","showlegend":true,"text":[6.73],"textposition":"inside","x":[6.73],"xaxis":"x","y":["Patron Silver"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Irish Whiskies\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Irish Whiskies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Irish Whiskies","offsetgroup":"Irish Whiskies","orientation":"h","showlegend":true,"text":[6.83],"textposition":"inside","x":[6.83],"xaxis":"x","y":["Jameson"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Imported Brandies\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Imported Brandies","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Imported Brandies","offsetgroup":"Imported Brandies","orientation":"h","showlegend":true,"text":[7.42],"textposition":"inside","x":[7.42],"xaxis":"x","y":["Hennessy Vs"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Tennessee Whiskies\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tennessee Whiskies","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Tennessee Whiskies","offsetgroup":"Tennessee Whiskies","orientation":"h","showlegend":true,"text":[9.52],"textposition":"inside","x":[9.52],"xaxis":"x","y":["Jack Daniels Old #7 Black Label"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Canadian Whiskies\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canadian Whiskies","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Canadian Whiskies","offsetgroup":"Canadian Whiskies","orientation":"h","showlegend":true,"text":[10.14,11.34,11.67],"textposition":"inside","x":[10.14,11.34,11.67],"xaxis":"x","y":["Crown Royal Regal Apple","Crown Royal","Black Velvet"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Spiced Rum\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spiced Rum","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Spiced Rum","offsetgroup":"Spiced Rum","orientation":"h","showlegend":true,"text":[10.36],"textposition":"inside","x":[10.36],"xaxis":"x","y":["Captain Morgan Original Spiced"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=Whiskey Liqueur\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Whiskey Liqueur","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Whiskey Liqueur","offsetgroup":"Whiskey Liqueur","orientation":"h","showlegend":true,"text":[11.84],"textposition":"inside","x":[11.84],"xaxis":"x","y":["Fireball Cinnamon Whiskey"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"category=American Vodkas\u003cbr\u003etotal_sales=%{text}\u003cbr\u003eitem=%{y}\u003cextra\u003e\u003c\u002fextra\u003e ...

# %% [markdown]
# # Highest sales (2022)

# %% [markdown]
# * **Stores with highest sales**

# %%
df10 = pd.read_csv(r"/content/10.csv")

df10.store = df10.store.str.title()

df10.total_sales = df10.total_sales.astype('float')

df10.head(10)
# Out:
#                                  store         county  bottle_sales  \
# 0         Hy-Vee #3 / Bdi / Des Moines           POLK        783709
# 1                       Central City 2           POLK        714031
# 2  Hy-Vee Wine And Spirits / Iowa City        JOHNSON        375823
# 3               Another Round / Dewitt        CLINTON        303982
# 4                    Benz Distributing           LINN        247865
# 5          Costco Wholesale #788 / Wdm         DALLAS        180429
# 6                       Wilkie Liquors           LINN        248572
# 7         I-80 Liquor / Council Bluffs  POTTAWATTAMIE        181916
# 8    Sam'S Club 6344 / Windsor Heights           POLK        155995
# 9       Sam'S Club 8162 / Cedar Rapids           LINN        153540
#
#    total_sales
# 0   14186029.0
# 1   13193789.0
# 2    5818035.0
# 3    5705737.0
# 4    4654694.0
# 5    4243802.0
# 6    3935156.0
# 7    3225773.0
# 8    3178966.0
# 9    3050270.0

# %% [markdown]
# *  **Hy-Vee Store with highest sales (2022)**

# %%
df10_1 = pd.read_csv(r"/content/hy-vee.csv")

df10_1.store = df10_1.store.str.title()

df10_1.total_sales = df10_1.total_sales.astype('float')

df10_1.head(10)
# Out:
#                                   store   county  bottle_sales  total_sales
# 0          Hy-Vee #3 / Bdi / Des Moines     POLK        783709   14186029.0
# 1   Hy-Vee Wine And Spirits / Iowa City  JOHNSON        375823    5818035.0
# 2         Hy-Vee Food Store / Urbandale     POLK        151593    3011367.0
# 3        Hy-Vee Food Store / Coralville  JOHNSON        146251    2616271.0
# 4                       Hy-Vee / Waukee   DALLAS        134539    2310716.0
# 5              Hy-Vee #7 / Cedar Rapids     LINN        122870    2252917.0
# 6         Hy-Vee Wine And Spirits / Wdm     POLK        121294    2234134.0
# 7  Hy-Vee Wine And Spirits / Bettendorf    SCOTT        125073    2129270.0
# 8   Hy-Vee Food Store #2 / State Ankeny     POLK        114576    2089551.0
# 9                     Hy-Vee  #2 / Ames    STORY        115693    2065575.0

# %% [markdown]
# * **Counties with highest sales (2022)**

# %%
df11 = pd.read_csv(r"/content/county.csv")

df11.county = df11.county.str.title()

df11.total_sales = df11.total_sales.astype('float')

df11.head(10)
# Out:
#           county  bottle_sales  total_sales
# 0           Polk       7022989  100630597.0
# 1           Linn       2695443   36039443.0
# 2          Scott       2134820   27283973.0
# 3        Johnson       1573336   24752492.0
# 4     Black Hawk       1728897   22484158.0
# 5  Pottawattamie       1188556   15574305.0
# 6       Woodbury       1086623   14524713.0
# 7         Dallas        688281   12992382.0
# 8          Story        823661   12738294.0
# 9        Dubuque        847246   11878676.0
